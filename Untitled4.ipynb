# %%
import matplotlib.pyplot as plt
import numpy as np

X1 = []
for line in open('dat1.txt', 'r'):
    values = [float(s) for s in line.split()]
    X1.append(values[0])

plt.plot(X1)
plt.show()

X2 = []
for line in open('dat2.txt', 'r'):
    values = [float(s) for s in line.split()]
    X2.append(values[0])
    
plt.plot(X2)
plt.show()

x1 = np.asarray(X1)
x2 = np.asarray(X2)
X = np.vstack((x1, x2))
X
# Out:
# array([[ 0.        ,  0.70299995,  0.7059996 , ...,  0.69222291,
#          0.69522224,  0.69822205],
#        [ 0.        , -0.49500008, -0.49000067, ..., -0.51296182,
#         -0.50796293, -0.50296325]])

# %%
len(X[0])
X[0][3000]
# Out:
# -0.9964094872278585

# %%
def centering(X):
    total = 0
    for i in range (0, len(X)):
        for j in range (0, len(X[i])):
            total = total + X[i][j]
        mean = total / len(X[i])
        X = X - mean
    return X

# %%
x=np.asarray([1,2,3])
x-1
# Out:
# array([0, 1, 2])

# %%
centering(X)
# Out:
# array([[-0.00744718,  0.69555277,  0.69855242, ...,  0.68477573,
#          0.68777506,  0.69077487],
#        [-0.00744718, -0.50244726, -0.49744784, ..., -0.52040899,
#         -0.51541011, -0.51041043]])

# %%
centering(X)
# Out:
# array([[-0.00744718,  0.69555277,  0.69855242, ...,  0.68477573,
#          0.68777506,  0.69077487],
#        [-0.00744718, -0.50244726, -0.49744784, ..., -0.52040899,
#         -0.51541011, -0.51041043]])

# %%
def mean(X):
    E = [[0],[0]]
    total = 0
    for i in range (0, len(X)):
        for j in range (0, len(X[i])):
            total = total + X[i][j]
        mean = total / len(X[i])
        E[i][0] = mean
    return E

# %%
mean(X)
# Out:
# [[0.026066084620083786], [0.00744717833762195]]

# %%
E1 = np.mean(x1)
E2 = np.mean(x2)
E = np.vstack((E1,E2))
E
# Out:
# array([[ 0.02606608],
#        [-0.01861891]])

# %%
tes1 = np.array([1,2])
tes2 = np.array([5,8])
tes = np.vstack((tes1, tes2))
print(tes1)
print(tes2)
# Out:
# [1 2]
# [5 8]

# %%
rata1 = np.mean(tes1)
rata2 = np.mean(tes2)
rata = np.vstack((rata1, rata2))
rata
# Out:
# array([[1.5],
#        [6.5]])

# %%
tes - rata
# Out:
# array([[-0.5,  0.5],
#        [-1.5,  1.5]])

# %%
X
# Out:
# array([[ 0.        ,  0.70299995,  0.7059996 , ...,  0.69222291,
#          0.69522224,  0.69822205],
#        [ 0.        , -0.49500008, -0.49000067, ..., -0.51296182,
#         -0.50796293, -0.50296325]])

# %%
E = np.transpose([np.mean(X, axis = 1)])

# %%
E
# Out:
# array([[ 0.02606608],
#        [-0.01861891]])

# %%
X - E
# Out:
# array([[-0.02606608,  0.67693387,  0.67993352, ...,  0.66615683,
#          0.66915616,  0.67215597],
#        [ 0.01861891, -0.47638118, -0.47138176, ..., -0.49434291,
#         -0.48934403, -0.48434434]])

# %%
np.transpose([np.mean(X-E, axis = 1)])
# Out:
# array([[-2.48757801e-17],
#        [-4.52286910e-18]])

# %%
def mean(X):
    E = np.zeros((len(X),1))
    for i in range (0, len(X)):
        total = 0
        for j in range (0, len(X[i])):
            total = total + X[i][j]
        mean = total / len(X[i])
        E[i][0] = mean
    return E

# %%
E = mean(X)

# %%
mean(X-E)
# Out:
# array([[-5.57231607e-17],
#        [ 7.16238724e-17]])

# %% [markdown]
# 1. https://numpy.org/doc/stable/reference/generated/numpy.zeros.html 02/07
# 2. https://numpy.org/doc/stable/reference/generated/numpy.array.html 02/07
# 3. https://numpy.org/doc/stable/reference/generated/numpy.matrix.shape.html 02/07
# 4. https://numpy.org/doc/stable/reference/generated/numpy.mean.html 02/07
# 5. https://numpy.org/doc/stable/reference/generated/numpy.identity.html 02/07
# 6. https://numpy.org/doc/stable/reference/random/generated/numpy.random.rand.html 02/07
# 7. https://numpy.org/doc/stable/reference/generated/numpy.linalg.norm.html 02/07
# 8. https://numpy.org/doc/stable/reference/generated/numpy.linalg.matrix_power.html 02/07

# %%
def sigma(X):
    a,b = X.shape
    temp = np.transpose(X)
    c,d = temp.shape
    sum = np.zeros((a,a))
    for i in range (0, c):
        x = np.zeros((d,1))
        for j in range(0, d):
            x[j][0] = temp[i][j]
        sum = sum + np.matmul(x, np.transpose(x))
    return sum / b

# %%
X
# Out:
# array([[ 0.        ,  0.70299995,  0.7059996 , ...,  0.69222291,
#          0.69522224,  0.69822205],
#        [ 0.        , -0.49500008, -0.49000067, ..., -0.51296182,
#         -0.50796293, -0.50296325]])

# %%
len(np.transpose(X)[1])
# Out:
# 2

# %%
np.transpose(X)[2][0]
# Out:
# 0.7059996000079999

# %%
len(X)
# Out:
# 2

# %%
a,b = X.shape

# %%
a
# Out:
# 2

# %%
b
# Out:
# 3142

# %%
np.array(((1,2),(3,4))) / 2
# Out:
# array([[0.5, 1. ],
#        [1.5, 2. ]])

# %%
X
# Out:
# array([[ 0.        ,  0.70299995,  0.7059996 , ...,  0.69222291,
#          0.69522224,  0.69822205],
#        [ 0.        , -0.49500008, -0.49000067, ..., -0.51296182,
#         -0.50796293, -0.50296325]])

# %%
E
# Out:
# array([[ 0.02606608],
#        [-0.01861891]])

# %%
X-E
# Out:
# array([[-0.02606608,  0.67693387,  0.67993352, ...,  0.66615683,
#          0.66915616,  0.67215597],
#        [ 0.01861891, -0.47638118, -0.47138176, ..., -0.49434291,
#         -0.48934403, -0.48434434]])

# %%
mean(X-E)
# Out:
# array([[-5.57231607e-17],
#        [ 7.16238724e-17]])

# %%
sigma(X-E)
# Out:
# array([[ 0.53433146, -0.27433077],
#        [-0.27433077,  0.37435198]])

# %%
d, e = np.linalg.eig(sigma(X-E))
print(d)
print(e)
# Out:
# [0.74009639 0.16858705]
# [[ 0.79997641  0.60003145]
#  [-0.60003145  0.79997641]]

# %%
a, b = X.shape
np.identity(a)
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
def eigval_mat(d, I):
    for i in range (0, len(d)):
        I[i] = I[i] * d[i]
    return I

# %%
D = eigval_mat(d, np.identity(a))
D
# Out:
# array([[0.74009639, 0.        ],
#        [0.        , 0.16858705]])

# %%
def pow_diag(D, n):
    for i in range (0, len(D)):
        for j in range(0, len(D[i])):
            if i == j:
                D[i][j] = D[i][j] ** n
    return D

# %%
pow_diag(D, -0.5)
# Out:
# array([[1.16240068, 0.        ],
#        [0.        , 2.43549866]])

# %%
D
# Out:
# array([[1.16240068, 0.        ],
#        [0.        , 2.43549866]])

# %%
V = np.matmul(np.matmul(e, D), np.transpose(e))

# %%
V
# Out:
# array([[1.620764  , 0.61110104],
#        [0.61110104, 1.97713534]])

# %%
X
# Out:
# array([[ 0.        ,  0.70299995,  0.7059996 , ...,  0.69222291,
#          0.69522224,  0.69822205],
#        [ 0.        , -0.49500008, -0.49000067, ..., -0.51296182,
#         -0.50796293, -0.50296325]])

# %%
Z = np.matmul(V, X-E)

# %%
Z
# Out:
# array([[-0.03086894,  0.80603301,  0.81394988, ...,  0.77758953,
#          0.78550556,  0.79342286],
#        [ 0.02088309, -0.52819507, -0.51647746, ..., -0.57029371,
#         -0.55857734, -0.54685911]])

# %%
sigma(Z)
# Out:
# array([[ 1.00000000e+00, -2.35989529e-15],
#        [-2.35989529e-15,  1.00000000e+00]])

# %%
print(a,b)
# Out:
# [1 2] 3142

# %%
W = np.random.rand(a,a)

# %%
W
# Out:
# array([[0.29182363, 0.37397645],
#        [0.79467552, 0.5245629 ]])

# %%
print(W[0])
print(W[1])
# Out:
# [0.52703353 0.42056542]
# [0.70042246 0.32765726]

# %%
def ortho(W):
    for i in range (0, len(W)):
        W[i] = W[i]/np.linalg.norm(W[i])
    return W

# %%
print(ortho(W))
print(W[0])
a = np.asarray([W[0]])
print(a.shape, a)
# Out:
# [[0.7816361  0.62373472]
#  [0.90578954 0.42372787]]
# [0.7816361  0.62373472]
# (1, 2) [[0.7816361  0.62373472]]

# %%
def renew(W):
    for i in range (0, len(W)):
        W[i] = np.transpose([W[i]])
        W[i] = mean(np.matmul(Z, np.linalg.matrix_power(np.matmul(np.transpose([W[i]]),Z),3))) - 3 * W[i]
    return W

# %%
W[1]
# Out:
# array([0.28468009, 0.95862258])

# %%
np.transpose([W[1]]) * 1
# Out:
# array([[0.28468009],
#        [0.95862258]])

# %%
renew(W)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-b65c29383d11> in <module>
# ----> 1 renew(W)
#
# <ipython-input-107-cab910afae3c> in renew(W)
#       1 def renew(W):
#       2     for i in range (0, len(W)):
# ----> 3         W[i] = np.transpose([W[i]])
#       4         W[i] = mean(np.matmul(Z, np.linalg.matrix_power(np.matmul(np.transpose([W[i]]),Z),3))) - 3 * W[i]
#       5     return W
#
# ValueError: could not broadcast input array from shape (2,1) into shape (2)

# %%
a = np.array((1,2))
a

np.transpose([a])
# Out:
# array([[1],
#        [2]])

# %%
W
# Out:
# array([[0.2451691 , 0.96948033],
#        [0.28468009, 0.95862258]])

# %%
transpose(W)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-101-0aba5c6b9bce> in <module>
# ----> 1 transpose(W)
#
# <ipython-input-98-0bb9a8418c78> in transpose(W)
#       1 def transpose(W):
#       2     for i in range(0, len(W)):
# ----> 3         W[i] = np.transpose([W[i]])
#       4     return W
#
# ValueError: could not broadcast input array from shape (2,1) into shape (2)

# %%
mean(np.matmul(Z, np.linalg.matrix_power(np.matmul(W,Z),3)))
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-116-42531468fe1e> in <module>
# ----> 1 mean(np.matmul(Z, np.linalg.matrix_power(np.matmul(W,Z),3)))
#
# <__array_function__ internals> in matrix_power(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in matrix_power(a, n)
#     620     a = asanyarray(a)
#     621     _assert_stacked_2d(a)
# --> 622     _assert_stacked_square(a)
#     623
#     624     try:
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in _assert_stacked_square(*arrays)
#     211         m, n = a.shape[-2:]
#     212         if m != n:
# --> 213             raise LinAlgError('Last 2 dimensions of the array must be square')
#     214
#     215 def _assert_finite(*arrays):
#
# LinAlgError: Last 2 dimensions of the array must be square

# %%
W
# Out:
# array([[0.7816361 , 0.62373472],
#        [0.90578954, 0.42372787]])

# %%
z_h, z_w = Z.shape
Z_W = np.transpose(Z)

# %%
Z_W[0]
# Out:
# array([-0.03086894,  0.02088309])

# %%
def update(W):
    for k in range(0, len(W)):
        for i in range(0, z_w):#z_w = 3142
            sum = np.zeros((z_h,1))
            z = np.zeros((z_h,1))
            for j in range(0, z_h): #z_h = 2
                z[j][0] = Z[j][i]
            D = np.matmul(np.asarray([W[k]]),z)
            E = np.asarray(D ** 3)
            sum = sum + np.matmul(z,E)            
            res = sum / z_w
            #C = np.transpose([Z_W[j]])
            #D = np.matmul(np.asarray([W[i]]),np.transpose([Z_W[j]]))
            #E = np.asarray(D ** 3)
        
        print("res shape:",res.shape)
        W[k] = np.transpose(res - np.transpose(np.asarray([3 * W[k]])))
        print('W shape:',W[k].shape)
        print('np asarray shape:',np.transpose(np.asarray([3 * W[k]])), np.transpose(np.asarray([3 * W[k]])).shape)
    return W

# %%
W = np.random.rand(2,2)

# %%
ortho(W)
update(W)
ortho(W)
# Out:
# res shape: (2, 1)
# W shape: (2,)
# np asarray shape: [[-7.04926174]
#  [-5.59533743]] (2, 1)
# res shape: (2, 1)
# W shape: (2,)
# np asarray shape: [[-8.2880978 ]
#  [-3.50801967]] (2, 1)
# array([[-0.78325183, -0.62170457],
#        [-0.92090676, -0.38978293]])

# %%
Y = np.matmul(W, Z)
Y
plt.plot(Y[0])
plt.plot(Y[1])
plt.show()

# %%
def kurtosis(y):

# %%
Z_W[0]
# Out:
# array([-0.03086894,  0.02088309])

# %%
Z
# Out:
# array([[-0.03086894,  0.80603301,  0.81394988, ...,  0.77758953,
#          0.78550556,  0.79342286],
#        [ 0.02088309, -0.52819507, -0.51647746, ..., -0.57029371,
#         -0.55857734, -0.54685911]])

# %%
W
# Out:
# array([[0.2451691 , 0.96948033],
#        [0.28468009, 0.95862258]])

# %%
np.zeros((z_h,1))
# Out:
# array([[0.],
#        [0.]])

# %%
np.linalg.matrix_power([3],3)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# <ipython-input-140-26fdb651adff> in <module>
# ----> 1 np.linalg.matrix_power([3],3)
#
# <__array_function__ internals> in matrix_power(*args, **kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in matrix_power(a, n)
#     619     """
#     620     a = asanyarray(a)
# --> 621     _assert_stacked_2d(a)
#     622     _assert_stacked_square(a)
#     623
#
# ~/anaconda3/lib/python3.8/site-packages/numpy/linalg/linalg.py in _assert_stacked_2d(*arrays)
#     204     for a in arrays:
#     205         if a.ndim < 2:
# --> 206             raise LinAlgError('%d-dimensional array given. Array must be '
#     207                     'at least two-dimensional' % a.ndim)
#     208
#
# LinAlgError: 1-dimensional array given. Array must be at least two-dimensional

# %%
np.asarray([3]) ** 3
# Out:
# array([27])

# %%
np.matmul(np.array([1,2]),np.array([[1],[2]]))
# Out:
# array([5])

# %%
np.asarray([W[1]]).shape
# Out:
# (1, 2)

# %%
np.transpose([Z_W[0]]).shape
# Out:
# (2, 1)

# %%
np.matmul(np.asarray([W[1]]),np.transpose([Z_W[4]]))
# Out:
# array([[-0.23642798]])

# %%
z_w
# Out:
# 3142

# %%
W[1]
# Out:
# array([0.28468009, 0.95862258])

# %%
update(W)
# Out:
# res shape: (2, 1)
# new W shape: (2,)
# np asarray shape: (2,)
# res shape: (2, 1)
# new W shape: (2,)
# np asarray shape: (2,)
# array([[178.72827063, 706.75116221],
#        [ 69.17726269, 232.94528612]])

# %%
np.asarray([3 * W[1]])
# Out:
# array([[0.85404028, 2.87586773]])

# %%
np.transpose(np.transpose([3 * W[1]]))
# Out:
# array([[0.85404028, 2.87586773]])

# %%
np.zeros((2,2))
# Out:
# array([[0., 0.],
#        [0., 0.]])

# %%
np.array([[0],[1]])
# Out:
# array([[0],
#        [1]])

# %%
np.zeros((z_h,1))
# Out:
# array([[0.],
#        [0.]])
