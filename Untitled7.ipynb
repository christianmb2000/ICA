# %%
import matplotlib.pyplot as plt
import numpy as np

import wave

# Read the wave file
mix_1_wave = wave.open('music1.wav','r')
mix_2_wave = wave.open('music2.wav','r')
from scipy.io import wavfile
sampling_rate, mix1 = wavfile.read('music1.wav')
sampling_rate, mix2 = wavfile.read('music2.wav')
plt.plot(mix1)
plt.show()
plt.plot(mix2)
plt.show()

X = np.vstack((mix1, mix2))

# %%
def mean(X):
    E = np.zeros((len(X),1))
    for i in range (0, len(X)):
        total = 0
        for j in range (0, len(X[i])):
            total = total + X[i][j]
        mean = total / len(X[i])
        E[i][0] = mean
    return E

E = mean(X)
mean(X-E)

def sigma(X):
    a,b = X.shape
    temp = np.transpose(X)
    c,d = temp.shape
    sum = np.zeros((a,a))
    for i in range (0, c):
        x = np.zeros((d,1))
        for j in range(0, d):
            x[j][0] = temp[i][j]
        sum = sum + np.matmul(x, np.transpose(x))
    return sum / b

sigma(X-E)
d, e = np.linalg.eig(sigma(X-E))
print(d)
print(e)

def eigval_mat(d, I):
    for i in range (0, len(d)):
        I[i] = I[i] * d[i]
    return I

a, b = X.shape
D = eigval_mat(d, np.identity(a))
D

def pow_diag(D, n):
    for i in range (0, len(D)):
        for j in range(0, len(D[i])):
            if i == j:
                D[i][j] = D[i][j] ** n
    return D

pow_diag(D, -0.5)
D

V = np.matmul(np.matmul(e, D), np.transpose(e))
V

Z = np.matmul(V, X-E)
sigma(Z)
# Out:
# [ 2435409.71268983 62750654.48686929]
# [[-0.73660912 -0.67631871]
#  [ 0.67631871 -0.73660912]]
# array([[ 1.00000000e+00, -1.72556798e-13],
#        [-1.72556798e-13,  1.00000000e+00]])

# %%
def ortho(W):
    for i in range (0, len(W)):
        W[i] = W[i]/np.linalg.norm(W[i])
    return W

def kurtosis(Y):
    kur = np.zeros((len(Y),1)) #len(X)or len(Y)
    kur = mean(Y**4)-3*(mean(Y**2)**2)
    return kur

def update2(W): #W = 2x2 = [[w1T],[w2T]]
    for k in range(0, len(W)):
        #print('W before:',W)
        res = np.zeros((len(W),1))
        total = np.zeros((len(W),1))
        for i in range(0, len(X[0])):#z_w = 3142 X = 2 x 3142    
            D = np.zeros((1,1))
            E = np.zeros((1,1))
            K = np.zeros((2,1))
            z = np.zeros((len(W),1))
            for j in range(0, len(W)): #z_h = 2
                z[j][0] = Z[j][i] #Z=2x3142
            D = np.matmul(np.asarray([W[k]]),z)
            E = D ** 3
            #print(np.matmul(z,E))
            K = np.matmul(z,E)
            total = total + K
        res = total / float(len(X[0]))
        W[k] = np.transpose(res - np.transpose(float(3) * np.asarray([W[k]]))) #problem?
        #print('W[k]:',W[k])
    #print('W after:',W,'\n')
    return W
        #print('res:',res)
            #C = np.transpose([Z_W[j]])
            #D = np.matmul(np.asarray([W[i]]),np.transpose([Z_W[j]]))
            #E = np.asarray(D ** 3)
        
        #print("res shape:",res.shape)
        #W[k] = np.transpose(res - np.transpose(3 * np.asarray([W[k]]))) #problem?
        #print('W shape:',W[k].shape)
        #print('np asarray shape:',np.transpose(np.asarray([3 * W[k]])), np.transpose(np.asarray([3 * W[k]])).shape)

def boushi(W):
    if all(np.abs(np.abs(W[0])-np.abs(W[1])) < np.array((1e-5,1e-5))):
        W[1] = np.random.rand(1,2)

# %%
W = np.random.rand(2,2)
ortho(W)
Y1 = np.matmul(W, Z)
print(W)
update2(W)
boushi(W)
ortho(W)
Y2 = np.matmul(W, Z)
print('kurtY1_start:',kurtosis(Y1))
print('kurtY2:',kurtosis(Y2),'\n')
while any(np.abs(kurtosis(Y1)) < np.abs(kurtosis(Y2))):
    ortho(W)
    Y1 = np.matmul(W, Z)
    print('W:',W)
    update2(W)
    ortho(W)
    Y2 = np.matmul(W, Z)
    boushi(W)
    print('kurtY1:',kurtosis(Y1))
    print('kurtY2:',kurtosis(Y2),'\n')

#Y2 = Y
print('Y:',Y2)
print('kurtY_end:',kurtosis(Y2))
for i in range (0, len(Y2)):
    plt.plot(Y2[i])
    plt.show()
# Out:
# [[0.48950221 0.87200206]
#  [0.85962287 0.51092907]]
# kurtY1_start: [[1.17275941]
#  [0.61293726]]
# kurtY2: [[1.59863723]
#  [0.61846392]]
#
# W: [[0.16928097 0.98556783]
#  [0.84100698 0.54102427]]
# kurtY1: [[1.59863723]
#  [0.61846392]]
# kurtY2: [[1.62190303]
#  [0.65684322]]
#
# W: [[0.08880294 0.99604921]
#  [0.78806138 0.61559668]]
# kurtY1: [[1.62190303]
#  [0.65684322]]
# kurtY2: [[1.62210196]
#  [0.90559443]]
#
# W: [[0.08131852 0.99668816]
#  [0.62671351 0.77924976]]
# kurtY1: [[1.62210196]
#  [0.90559443]]
# kurtY2: [[1.62210345]
#  [1.49760721]]
#
# W: [[0.08066949 0.99674091]
#  [0.28666301 0.95803148]]
# kurtY1: [[1.62210345]
#  [1.49760721]]
# kurtY2: [[1.62210346]
#  [1.62042099]]
#
# W: [[0.08061333 0.99674545]
#  [0.10434247 0.99454143]]
# kurtY1: [[1.62210346]
#  [1.62042099]]
# kurtY2: [[1.62210346]
#  [1.62209067]]
#
# W: [[0.08060847 0.99674584]
#  [0.08267865 0.99657626]]
# kurtY1: [[1.62210346]
#  [1.62209067]]
# kurtY2: [[1.62210346]
#  [1.62210337]]
#
# W: [[0.08060805 0.99674588]
#  [0.08078724 0.99673137]]
# kurtY1: [[1.62210346]
#  [1.62210337]]
# kurtY2: [[1.62210346]
#  [1.62210346]]
#
# W: [[0.08060801 0.99674588]
#  [0.08062351 0.99674463]]
# kurtY1: [[1.62210346]
#  [1.62210346]]
# kurtY2: [[1.62210346]
#  [1.62210346]]
#
# W: [[0.08060801 0.99674588]
#  [0.36048333 0.93276566]]
# kurtY1: [[1.62210346]
#  [1.39757602]]
# kurtY2: [[1.62210346]
#  [1.61747205]]
#
# W: [[0.08060801 0.99674588]
#  [0.11997918 0.99277641]]
# kurtY1: [[1.62210346]
#  [1.61747205]]
# kurtY2: [[1.62210346]
#  [1.6220676 ]]
#
# W: [[0.08060801 0.99674588]
#  [0.08407476 0.99645945]]
# kurtY1: [[1.62210346]
#  [1.6220676 ]]
# kurtY2: [[1.62210346]
#  [1.62210319]]
#
# W: [[0.08060801 0.99674588]
#  [0.08090819 0.99672156]]
# kurtY1: [[1.62210346]
#  [1.62210319]]
# kurtY2: [[1.62210346]
#  [1.62210346]]
#
# W: [[0.08060801 0.99674588]
#  [0.08063398 0.99674378]]
# kurtY1: [[1.62210346]
#  [1.62210346]]
# kurtY2: [[1.62210346]
#  [1.62210346]]
#
# W: [[0.08060801 0.99674588]
#  [0.99595763 0.08982428]]
# kurtY1: [[1.62210346]
#  [0.77934375]]
# kurtY2: [[1.62210346]
#  [0.80955578]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99949663 -0.03172528]]
# kurtY1: [[1.62210346]
#  [0.80955578]]
# kurtY2: [[1.62210346]
#  [0.81137688]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99804355 -0.06252256]]
# kurtY1: [[1.62210346]
#  [0.81137688]]
# kurtY2: [[1.62210346]
#  [0.8114353 ]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99768207 -0.06804775]]
# kurtY1: [[1.62210346]
#  [0.8114353 ]]
# kurtY2: [[1.62210346]
#  [0.81143707]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99761606 -0.06900869]]
# kurtY1: [[1.62210346]
#  [0.81143707]]
# kurtY2: [[1.62210346]
#  [0.81143712]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99760452 -0.06917535]]
# kurtY1: [[1.62210346]
#  [0.81143712]]
# kurtY2: [[1.62210346]
#  [0.81143712]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99760251 -0.06920425]]
# kurtY1: [[1.62210346]
#  [0.81143712]]
# kurtY2: [[1.62210346]
#  [0.81143712]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99760216 -0.06920925]]
# kurtY1: [[1.62210346]
#  [0.81143712]]
# kurtY2: [[1.62210346]
#  [0.81143712]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.9976021  -0.06921012]]
# kurtY1: [[1.62210346]
#  [0.81143712]]
# kurtY2: [[1.62210346]
#  [0.81143712]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99760209 -0.06921027]]
# kurtY1: [[1.62210346]
#  [0.81143712]]
# kurtY2: [[1.62210346]
#  [0.81143712]]
#
# W: [[ 0.08060801  0.99674588]
#  [ 0.99760209 -0.0692103 ]]
# kurtY1: [[1.62210346]
#  [0.81143712]]
# kurtY2: [[1.62210346]
#  [0.81143712]]
#
# Y: [[0.00114634 0.00114634 0.00114634 ... 0.00114634 0.00114634 0.00114634]
#  [0.00208012 0.00208012 0.00208012 ... 0.00208012 0.00208012 0.00208012]]
# kurtY_end: [[1.62210346]
#  [0.81143712]]

# %%
wavfile.write('mu3out1.wav', sampling_rate, Y2[0])
wavfile.write('mu3out2.wav', sampling_rate, Y2[1])
