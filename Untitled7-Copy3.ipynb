# %%
import matplotlib.pyplot as plt
import numpy as np

import wave

# Read the wave file
mix_1_wave = wave.open('speechB1.wav','r')
mix_2_wave = wave.open('speechB2.wav','r')
mix_3_wave = wave.open('speechB3.wav','r')
from scipy.io import wavfile
sampling_rate, mix1 = wavfile.read('speechB1.wav')
sampling_rate, mix2 = wavfile.read('speechB2.wav')
sampling_rate, mix3 = wavfile.read('speechB3.wav')
plt.plot(mix1)
plt.show()
plt.plot(mix2)
plt.show()
plt.plot(mix3)
plt.show()

X = np.vstack((mix1, mix2,mix3))

# %%
def mean(X):
    E = np.zeros((len(X),1))
    for i in range (0, len(X)):
        total = 0
        for j in range (0, len(X[i])):
            total = total + X[i][j]
        mean = total / len(X[i])
        E[i][0] = mean
    return E

E = mean(X)
mean(X-E)

def sigma(X):
    a,b = X.shape
    temp = np.transpose(X)
    c,d = temp.shape
    sum = np.zeros((a,a))
    for i in range (0, c):
        x = np.zeros((d,1))
        for j in range(0, d):
            x[j][0] = temp[i][j]
        sum = sum + np.matmul(x, np.transpose(x))
    return sum / b

sigma(X-E)
d, e = np.linalg.eig(sigma(X-E))
print(d)
print(e)

def eigval_mat(d, I):
    for i in range (0, len(d)):
        I[i] = I[i] * d[i]
    return I

a, b = X.shape
D = eigval_mat(d, np.identity(a))
D

def pow_diag(D, n):
    for i in range (0, len(D)):
        for j in range(0, len(D[i])):
            if i == j:
                D[i][j] = D[i][j] ** n
    return D

pow_diag(D, -0.5)
D

V = np.matmul(np.matmul(e, D), np.transpose(e))
V

Z = np.matmul(V, X-E)
sigma(Z)
# Out:
# [15714940.85362036   163948.76092838   155242.35374118]
# [[-0.58134719 -0.80055816  0.14540315]
#  [-0.57358624  0.2764768  -0.77107678]
#  [-0.57709121  0.53166457  0.61991816]]
# array([[ 1.00000000e+00,  1.84074215e-13, -1.82178740e-13],
#        [ 1.84074215e-13,  1.00000000e+00,  2.90048796e-13],
#        [-1.82178740e-13,  2.90048796e-13,  1.00000000e+00]])

# %%
def ortho(W):
    for i in range (0, len(W)):
        W[i] = W[i]/np.linalg.norm(W[i])
    return W

def kurtosis(Y):
    kur = np.zeros((len(Y),1)) #len(X)or len(Y)
    kur = mean(Y**4)-3*(mean(Y**2)**2)
    return kur

def update2(W): #W = 2x2 = [[w1T],[w2T]]
    for k in range(0, len(W)):
        #print('W before:',W)
        res = np.zeros((len(W),1))
        total = np.zeros((len(W),1))
        for i in range(0, len(X[0])):#z_w = 3142 X = 2 x 3142    
            D = np.zeros((1,1))
            E = np.zeros((1,1))
            K = np.zeros((3,1))
            z = np.zeros((len(W),1))
            for j in range(0, len(W)): #z_h = 2
                z[j][0] = Z[j][i] #Z=2x3142
            D = np.matmul(np.asarray([W[k]]),z)
            E = D ** 3
            #print(np.matmul(z,E))
            K = np.matmul(z,E)
            total = total + K
        res = total / float(len(X[0]))
        W[k] = np.transpose(res - np.transpose(float(3) * np.asarray([W[k]]))) #problem?
        #print('W[k]:',W[k])
    #print('W after:',W,'\n')
    return W
        #print('res:',res)
            #C = np.transpose([Z_W[j]])
            #D = np.matmul(np.asarray([W[i]]),np.transpose([Z_W[j]]))
            #E = np.asarray(D ** 3)
        
        #print("res shape:",res.shape)
        #W[k] = np.transpose(res - np.transpose(3 * np.asarray([W[k]]))) #problem?
        #print('W shape:',W[k].shape)
        #print('np asarray shape:',np.transpose(np.asarray([3 * W[k]])), np.transpose(np.asarray([3 * W[k]])).shape)

def boushi(W):
    if all(np.abs(np.abs(W[0])-np.abs(W[1])) < np.array((1e-5,1e-5,1e-5))):
        W[1] = np.random.rand(1,3)
    if all(np.abs(np.abs(W[1])-np.abs(W[2])) < np.array((1e-5,1e-5,1e-5))):
        W[2] = np.random.rand(1,3)
    if all(np.abs(np.abs(W[2])-np.abs(W[0])) < np.array((1e-5,1e-5,1e-5))):
        W[0] = np.random.rand(1,3)

# %%
W = np.array([[0.081, 0.997, 0.500],[0.998, -0.069, 0.500],[0.320, -0.642, -0.500]])
ortho(W)
Y1 = np.matmul(W, Z)
print(W)
update2(W)
boushi(W)
ortho(W)
Y2 = np.matmul(W, Z)
print('kurtY1_start:',kurtosis(Y1))
print('kurtY2:',kurtosis(Y2),'\n')
while any(np.abs(kurtosis(Y1)) < np.abs(kurtosis(Y2))):
#while all(np.abs(np.abs(kurtosis(Y1))-np.abs(kurtosis(Y2))) < np.array((1e-3,1e-3))):
    ortho(W)
    Y1 = np.matmul(W, Z)
    print('W:',W)
    update2(W)
    ortho(W)
    Y2 = np.matmul(W, Z)
    boushi(W)
    print('kurtY1:',kurtosis(Y1))
    print('kurtY2:',kurtosis(Y2),'\n')

#Y2 = Y
print('Y:',Y2)
print('kurtY_end:',kurtosis(Y2))
for i in range (0, len(Y2)):
    plt.plot(Y2[i])
    plt.show()
# Out:
# [[ 0.07243209  0.89154066  0.44711167]
#  [ 0.89236531 -0.0616966   0.44707681]
#  [ 0.36596795 -0.7342232  -0.57182493]]
# kurtY1_start: [[1.77595338]
#  [1.50947855]
#  [1.1740438 ]]
# kurtY2: [[2.45841347]
#  [1.97407003]
#  [1.63433659]]
#
# W: [[-0.01147186  0.98634221  0.16430897]
#  [ 0.97757494  0.02983331  0.20846395]
#  [ 0.10341815 -0.85713697 -0.50459974]]
# kurtY1: [[2.45841347]
#  [1.97407003]
#  [1.63433659]]
# kurtY2: [[2.60038517]
#  [2.15434369]
#  [2.29091512]]
#
# W: [[-0.00913884  0.99993896  0.00621007]
#  [ 0.99952261  0.02185708  0.02183626]
#  [ 0.01248844 -0.96769387 -0.25181859]]
# kurtY1: [[2.60038517]
#  [2.15434369]
#  [2.29091512]]
# kurtY2: [[2.60152045]
#  [2.16054259]
#  [2.59525299]]
#
# W: [[-0.00743324  0.99993978 -0.00807386]
#  [ 0.99969041  0.02056823 -0.01400138]
#  [ 0.00994829 -0.99959329 -0.0267261 ]]
# kurtY1: [[2.60152045]
#  [2.16054259]
#  [2.59525299]]
# kurtY2: [[2.60152382]
#  [2.16062671]
#  [2.60150458]]
#
# W: [[-0.00731827  0.99993406 -0.00884978]
#  [ 0.99962675  0.02039865 -0.01817298]
#  [ 0.00765584 -0.99994657  0.00694642]]
# kurtY1: [[2.60152382]
#  [2.16062671]
#  [2.60150458]]
# kurtY2: [[2.60152383]
#  [2.16062785]
#  [2.60152377]]
#
# W: [[-0.00731279  0.99993372 -0.00889216]
#  [ 0.99961814  0.0203812  -0.01865945]
#  [ 0.00732408 -0.99993457  0.00878752]]
# kurtY1: [[2.60152383]
#  [2.16062785]
#  [2.60152377]]
# kurtY2: [[2.60152383]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 0.66187149  0.4847913   0.57175478]
#  [ 0.99961712  0.02037907 -0.01871631]
#  [ 0.00731336 -0.99993375  0.0088888 ]]
# kurtY1: [[0.94798359]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[1.16879389]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 0.69087553  0.30154462  0.65708587]
#  [ 0.999617    0.02037883 -0.01872296]
#  [ 0.00731248 -0.99993371  0.00889428]]
# kurtY1: [[1.16879389]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[1.48373482]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 0.63706205  0.07381869  0.76726967]
#  [ 0.99961699  0.0203788  -0.01872373]
#  [ 0.00731244 -0.99993371  0.00889458]]
# kurtY1: [[1.48373482]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.19308102]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 0.40397992  0.02128974  0.91452008]
#  [ 0.99961699  0.0203788  -0.01872383]
#  [ 0.00731244 -0.99993371  0.0088946 ]]
# kurtY1: [[2.19308102]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.91856978]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 0.09173943  0.01123488  0.99571967]
#  [ 0.99961699  0.0203788  -0.01872384]
#  [ 0.00731244 -0.9999337   0.0088946 ]]
# kurtY1: [[2.91856978]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.96356031]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 0.0083314   0.00632804  0.99994527]
#  [ 0.99961699  0.0203788  -0.01872384]
#  [ 0.00731244 -0.9999337   0.0088946 ]]
# kurtY1: [[2.96356031]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.96391692]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 9.43705530e-04  5.41189490e-03  9.99984910e-01]
#  [ 9.99616988e-01  2.03787964e-02 -1.87238372e-02]
#  [ 7.31243750e-03 -9.99933705e-01  8.89459760e-03]]
# kurtY1: [[2.96391692]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.96391954]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 3.13817407e-04  5.31131427e-03  9.99985846e-01]
#  [ 9.99616988e-01  2.03787964e-02 -1.87238372e-02]
#  [ 7.31243750e-03 -9.99933705e-01  8.89459760e-03]]
# kurtY1: [[2.96391954]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 2.59793379e-04  5.30170169e-03  9.99985912e-01]
#  [ 9.99616988e-01  2.03787964e-02 -1.87238372e-02]
#  [ 7.31243750e-03 -9.99933705e-01  8.89459760e-03]]
# kurtY1: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 2.55150858e-04  5.30083150e-03  9.99985918e-01]
#  [ 9.99616988e-01  2.03787964e-02 -1.87238372e-02]
#  [ 7.31243750e-03 -9.99933705e-01  8.89459760e-03]]
# kurtY1: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 2.54751550e-04  5.30075467e-03  9.99985918e-01]
#  [ 9.99616988e-01  2.03787964e-02 -1.87238372e-02]
#  [ 7.31243750e-03 -9.99933705e-01  8.89459760e-03]]
# kurtY1: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
#
# W: [[ 2.54717189e-04  5.30074797e-03  9.99985918e-01]
#  [ 9.99616988e-01  2.03787964e-02 -1.87238372e-02]
#  [ 7.31243750e-03 -9.99933705e-01  8.89459760e-03]]
# kurtY1: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
# kurtY2: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]
#
# Y: [[ 0.0007041   0.0007041   0.0007041  ...  0.0007041   0.0007041
#    0.0007041 ]
#  [ 0.00031952  0.00031952  0.00031952 ...  0.00031952  0.00031952
#    0.00031952]
#  [-0.00045641 -0.00045641 -0.00045641 ... -0.00045641 -0.00045641
#   -0.00045641]]
# kurtY_end: [[2.96391956]
#  [2.16062787]
#  [2.60152383]]

# %%
wavfile.write('B1out1.wav', sampling_rate, Y2[0])
wavfile.write('B1out2.wav', sampling_rate, Y2[1])
wavfile.write('B1out3.wav', sampling_rate, Y2[2])
