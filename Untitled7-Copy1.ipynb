# %%
import matplotlib.pyplot as plt
import numpy as np

import wave

# Read the wave file
mix_1_wave = wave.open('music1.wav','r')
mix_2_wave = wave.open('music2.wav','r')
from scipy.io import wavfile
sampling_rate, mix1 = wavfile.read('music1.wav')
sampling_rate, mix2 = wavfile.read('music2.wav')
plt.plot(mix1)
plt.show()
plt.plot(mix2)
plt.show()

X = np.vstack((mix1, mix2))

# %%
def mean(X):
    E = np.zeros((len(X),1))
    for i in range (0, len(X)):
        total = 0
        for j in range (0, len(X[i])):
            total = total + X[i][j]
        mean = total / len(X[i])
        E[i][0] = mean
    return E

E = mean(X)
mean(X-E)

def sigma(X):
    a,b = X.shape
    temp = np.transpose(X)
    c,d = temp.shape
    sum = np.zeros((a,a))
    for i in range (0, c):
        x = np.zeros((d,1))
        for j in range(0, d):
            x[j][0] = temp[i][j]
        sum = sum + np.matmul(x, np.transpose(x))
    return sum / b

sigma(X-E)
d, e = np.linalg.eig(sigma(X-E))
print(d)
print(e)

def eigval_mat(d, I):
    for i in range (0, len(d)):
        I[i] = I[i] * d[i]
    return I

a, b = X.shape
D = eigval_mat(d, np.identity(a))
D

def pow_diag(D, n):
    for i in range (0, len(D)):
        for j in range(0, len(D[i])):
            if i == j:
                D[i][j] = D[i][j] ** n
    return D

pow_diag(D, -0.5)
D

V = np.matmul(np.matmul(e, D), np.transpose(e))
V

Z = np.matmul(V, X-E)
sigma(Z)
# Out:
# [ 2435409.71268983 62750654.48686929]
# [[-0.73660912 -0.67631871]
#  [ 0.67631871 -0.73660912]]
# array([[ 1.00000000e+00, -1.72556798e-13],
#        [-1.72556798e-13,  1.00000000e+00]])

# %%
def ortho(W):
    for i in range (0, len(W)):
        W[i] = W[i]/np.linalg.norm(W[i])
    return W

def kurtosis(Y):
    kur = np.zeros((len(Y),1)) #len(X)or len(Y)
    kur = mean(Y**4)-3*(mean(Y**2)**2)
    return kur

def update2(W): #W = 2x2 = [[w1T],[w2T]]
    for k in range(0, len(W)):
        #print('W before:',W)
        res = np.zeros((len(W),1))
        total = np.zeros((len(W),1))
        for i in range(0, len(X[0])):#z_w = 3142 X = 2 x 3142    
            D = np.zeros((1,1))
            E = np.zeros((1,1))
            K = np.zeros((2,1))
            z = np.zeros((len(W),1))
            for j in range(0, len(W)): #z_h = 2
                z[j][0] = Z[j][i] #Z=2x3142
            D = np.matmul(np.asarray([W[k]]),z)
            E = D ** 3
            #print(np.matmul(z,E))
            K = np.matmul(z,E)
            total = total + K
        res = total / float(len(X[0]))
        W[k] = np.transpose(res - np.transpose(float(3) * np.asarray([W[k]]))) #problem?
        #print('W[k]:',W[k])
    #print('W after:',W,'\n')
    return W
        #print('res:',res)
            #C = np.transpose([Z_W[j]])
            #D = np.matmul(np.asarray([W[i]]),np.transpose([Z_W[j]]))
            #E = np.asarray(D ** 3)
        
        #print("res shape:",res.shape)
        #W[k] = np.transpose(res - np.transpose(3 * np.asarray([W[k]]))) #problem?
        #print('W shape:',W[k].shape)
        #print('np asarray shape:',np.transpose(np.asarray([3 * W[k]])), np.transpose(np.asarray([3 * W[k]])).shape)

def boushi(W):
    if all(np.abs(np.abs(W[0])-np.abs(W[1])) < np.array((1e-5,1e-5))):
        W[1] = np.random.rand(1,2)

# %%
W = np.array([[0.081, 0.997],[0.998, -0.069]])
ortho(W)
Y1 = np.matmul(W, Z)
print(W)
update2(W)
boushi(W)
ortho(W)
Y2 = np.matmul(W, Z)
print('kurtY1_start:',kurtosis(Y1))
print('kurtY2:',kurtosis(Y2),'\n')
while any(np.abs(kurtosis(Y1)) < np.abs(kurtosis(Y2))):
    ortho(W)
    Y1 = np.matmul(W, Z)
    print('W:',W)
    update2(W)
    ortho(W)
    Y2 = np.matmul(W, Z)
    boushi(W)
    print('kurtY1:',kurtosis(Y1))
    print('kurtY2:',kurtosis(Y2),'\n')

#Y2 = Y
print('Y:',Y2)
print('kurtY_end:',kurtosis(Y2))
for i in range (0, len(Y2)):
    plt.plot(Y2[i])
    plt.show()
# Out:
# [[ 0.4472136   0.89442719]
#  [-0.6         0.8       ]]
# kurtY1_start: [[1.25178156]
#  [0.72935659]]
# kurtY2: [[1.60817427]
#  [1.27178137]]
#
# W: [[ 0.14889455  0.98885308]
#  [-0.28425738  0.95874801]]
# kurtY1: [[1.60817427]
#  [1.27178137]]
# kurtY2: [[1.62199006]
#  [1.61167506]]
#
# W: [[0.08677248 0.99622816]
#  [0.02128054 0.99977354]]
# kurtY1: [[1.62199006]
#  [1.61167506]]
# kurtY2: [[1.62210261]
#  [1.62202332]]
#
# W: [[0.08114216 0.99670254]
#  [0.07542377 0.99715157]]
# kurtY1: [[1.62210261]
#  [1.62202332]]
# kurtY2: [[1.62210346]
#  [1.62210286]]
#
# W: [[0.08065423 0.99674214]
#  [0.08015985 0.99678202]]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-f24332e15b19> in <module>
#      13     Y1 = np.matmul(W, Z)
#      14     print('W:',W)
# ---> 15     update2(W)
#      16     ortho(W)
#      17     Y2 = np.matmul(W, Z)
#
# <ipython-input-3-eb72582478d8> in update2(W)
#      20             z = np.zeros((len(W),1))
#      21             for j in range(0, len(W)): #z_h = 2
# ---> 22                 z[j][0] = Z[j][i] #Z=2x3142
#      23             D = np.matmul(np.asarray([W[k]]),z)
#      24             E = D ** 3
#
# KeyboardInterrupt:

# %%
W = np.array([[0.081, 0.997],[0.998, -0.069]])
Y2 = np.matmul(W, Z)

wavfile.write('mu4out1.wav', sampling_rate, Y2[0])
wavfile.write('mu4out2.wav', sampling_rate, Y2[1])
